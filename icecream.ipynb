# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
import os
os.chdir("gdrive/My Drive/dsplab")

# %%
import csv
#retriving data from csv file
print("Enter the value::")
preference=input()
count=0
counter=0
counting=0
list=[]
with open("sr.csv", 'r') as file:
  data = csv.reader(file)
  # for row in data:
  #   print(row)
  #retirving one column value based on another column value
  for value in data:
    if value[5]==preference:
      if(value[3]=="chocolate"):
        count=count+1
      if(value[3]=="kulfi"):
        counter=counter+1
      if(value[3]=="vanila"):
        counting=counting+1
      list.append(value[3])
print(list)
if(count>counter):
  if(count>counting):
    print("The person who prefers 3rd prefernce as")
    print(preference)
    print("likes mostly chocolate")
if(counter>count):
  if(counter>counting):
    print("The person who prefers 3rd prefernce as")
    print(preference)
    print("likes mostly kulfi")
if(counting>counter):
  if(counting>count):
    print("The person who prefers 3rd prefernce as")
    print(preference)
    print("likes mostly vanila")
else:
  print("Prefering all flavors as same")
